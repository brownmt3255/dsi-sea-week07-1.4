# %% [markdown]
# ## Today we are going to test your knowledge in SQL. Please refer to  http://www.w3schools.com/sql/ for any questions you might have over the material. Each question must be solved in only ONE SQL statement. No pandas or numpy operations may be used!
# ### These questions get progressively more difficult. Look through the website above and stackoverflow for hints on solving the more challenging problems.
# ### Unfortunately, Brad will only be able to give help on questions with difficulty 7 and higher. He apologizes for the inconvenience.

# %% [markdown]
# #### First create a connection to your postgresql database here

# %%
from sqlalchemy import create_engine
import pandas as pd
engine = create_engine('postgres://mfnyeqfz:zxzi25vFYOiloQ8ORKUo2-Oog5GgfZc2@elmer.db.elephantsql.com:5432/mfnyeqfz')
pd.read_sql("SELECT * FROM information_schema.tables;", engine)[:3]
# Out:
#   table_catalog table_schema          table_name  table_type  \
# 0      mfnyeqfz       public  pg_stat_statements        VIEW
# 1      mfnyeqfz       public        trump_tweets  BASE TABLE
# 2      mfnyeqfz       public        website_imdb  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                 NO       NO
# 1                     None                   None                YES       NO
# 2                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 1          None
# 2          None

# %% [markdown]
# #### Let's use the "website_imdb" table for our queries

# %% [markdown]
# ## Difficulty => 1

# %% [markdown]
# ### Print out all the drama movies

# %% [raw]
# pd.read_sql("SELECT * FROM website_imdb WHERE genre LIKE '%%Drama%%' ;", engine)

# %% [markdown]
# ### Print out all the movies with a director with 'C' or 'S' in their last names. Ignore any movies with multiple directors.

# %%
df_imdb_all = pd.read_sql("SELECT * FROM website_imdb WHERE director LIKE '%% C%%' OR director LIKE '%% S%%' AND director NOT LIKE '%%,%%' ;", engine)

df_imdb_all.head()
# Out:
#      id                    title  \
# 0  2740        Good Will Hunting
# 1  2721                 Whiplash
# 2  2723  Raiders of the Lost Ark
# 3  2728        The Wages of Fear
# 4  2735         The Great Escape
#
#                                               poster  \
# 0  http://ia.media-imdb.com/images/M/MV5BMTk0NjY0...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
# 3  https://images-na.ssl-images-amazon.com/images...
# 4  https://images-na.ssl-images-amazon.com/images...
#
#                                                 plot  \
# 0  Will Hunting, a janitor at M.I.T., has a gift ...
# 1  A promising young drummer enrolls at a cut-thr...
# 2  Archaeologist and adventurer Indiana Jones is ...
# 3  In a decrepit South American village, men are ...
# 4  Allied P.O.W.s plan for several hundred of the...
#
#                         genre  year  imdbRating  \
# 0                       Drama  1997         8.3
# ...

# %% [markdown]
# ## Difficulty => 3

# %% [markdown]
# ### Print out the gross of each director's highest grossing movie. Filter nan.

# %%
pd.read_sql("SELECT director, title, gross FROM website_imdb db1 WHERE gross <> 'NaN' AND db1.gross IN (select max(db2.gross) from website_imdb db2 where db2.director = db1.director)", engine)
# Out:
#                                       director  \
# 0                            Mathieu Kassovitz
# 1                                 Gus Van Sant
# 2                              Damien Chazelle
# 3                                   David Lean
# 4                      Aamir Khan, Amole Gupte
# 5                        Alejandro G. Iñárritu
# 6                      Wai-Keung Lau, Alan Mak
# 7                  Andrew Stanton, Lee Unkrich
# 8                         Joseph L. Mankiewicz
# 9    Pete Docter, David Silverman, Lee Unkrich
# 10                               Terry Gilliam
# 11                         Oliver Hirschbiegel
# 12                                  Tomm Moore
# 13                                Tom McCarthy
# 14                               Curtis Hanson
# 15                             Rajkumar Hirani
# 16                                  Ron Howard
# 17                           Richard Linklater
# 18                               Morten Tyldum
# ...

# %% [markdown]
# ### Print out the gross of each director's highest grossing movie. Order by gross desc. Filter nan.

# %%
pd.read_sql("SELECT director, title, gross FROM website_imdb db1 WHERE gross <> 'NaN' AND db1.gross IN (select max(db2.gross) from website_imdb db2 where db2.director = db1.director) ORDER BY gross DESC", engine)
# Out:
#                                       director  \
# 0                                  J.J. Abrams
# 1                            Christopher Nolan
# 2                                 George Lucas
# 3                    Roger Allers, Rob Minkoff
# 4                                  Lee Unkrich
# 5                                  David Yates
# 6                  Andrew Stanton, Lee Unkrich
# 7                                Peter Jackson
# 8                                   Tim Miller
# 9                             Steven Spielberg
# 10              Pete Docter, Ronnie Del Carmen
# 11        Byron Howard, Rich Moore, Jared Bush
# 12                                  James Gunn
# 13                             Robert Zemeckis
# 14                            Richard Marquand
# 15                              Gore Verbinski
# 16                          M. Night Shyamalan
# 17                   Pete Docter, Bob Peterson
# 18                              Irvin Kershner
# ...

# %% [markdown]
# ## Difficulty => 5

# %% [markdown]
# ### Print out the movie title, gross, and director of each director's highest grossing movie. Order by gross desc. Filter nan.

# %%
# Max Gross Per Director
db1 = pd.read_sql("SELECT director FROM website_imdb GROUP BY director HAVING count(director) > 1", engine)
# Directors with > 1 Movies
db2 = pd.read_sql("SELECT director FROM website_imdb GROUP BY director HAVING count(director) > 1", engine)
# All in one
pd.read_sql("SELECT db1.director, db1.title, db1.gross FROM website_imdb db1, (select director,max(gross) as max_gross from website_imdb group by director) as db2, (select director from website_imdb group by director having count(director) > 1) as db3 WHERE db1.gross <> 'NaN' AND db1.director = db3.director and db1.gross = db2.max_gross GROUP BY db1.director,db1.title,db1.gross ORDER BY gross DESC", engine)
# Out:
#                  director                                          title  \
# 0       Christopher Nolan                                The Dark Knight
# 1           Peter Jackson  The Lord of the Rings: The Return of the King
# 2        Steven Spielberg                                  Jurassic Park
# 3         Robert Zemeckis                                   Forrest Gump
# 4            Ridley Scott                                    The Martian
# 5           James Cameron                     Terminator 2: Judgment Day
# 6   Alejandro G. Iñárritu                                   The Revenant
# 7              Ron Howard                               A Beautiful Mind
# 8           David Fincher                                      Gone Girl
# 9       Quentin Tarantino                               Django Unchained
# 10        George Roy Hill                                      The Sting
# 11         Clint Eastwood                                    Gran Torino
# ...

# %%
# Same answer using IN statement
pd.read_sql("SELECT director, title, gross FROM website_imdb db1 WHERE gross <> 'NaN' AND db1.gross IN (select max(db2.gross) from website_imdb db2 where db2.director = db1.director) ORDER BY gross DESC LIMIT 3", engine)
# Out:
#             director                               title        gross
# 0        J.J. Abrams        Star Wars: The Force Awakens  936627416.0
# 1  Christopher Nolan                     The Dark Knight  533316061.0
# 2       George Lucas  Star Wars: Episode IV - A New Hope  460935665.0

# %% [markdown]
# ### Print out the movie title, rating, and director of each director's highest rated movie if that director has directed more than one movie. Order by rating desc. Filter nan.

# %%
pd.read_sql('SELECT db1.director, db1.title, db1."imdbRating" FROM website_imdb db1, (select director,max("imdbRating") as max_imdbrating from website_imdb group by director) as db2, (select director from website_imdb group by director having count(director) > 1) as db3 WHERE db1."imdbRating" <> \'NaN\' AND db1.director = db3.director and db1."imdbRating" = db2.max_imdbrating GROUP BY db1.director,db1.title,db1."imdbRating" ORDER BY db1."imdbRating" DESC', engine)
# Out:
#                   director                                              title  \
# 0           Frank Darabont                           The Shawshank Redemption
# 1     Francis Ford Coppola                                      The Godfather
# 2        Christopher Nolan                                    The Dark Knight
# 3     Francis Ford Coppola                             The Godfather: Part II
# 4            Peter Jackson      The Lord of the Rings: The Return of the King
# 5        Quentin Tarantino                                       Pulp Fiction
# 6             Sergio Leone                     The Good, the Bad and the Ugly
# 7             Sidney Lumet                                       12 Angry Men
# 8         Steven Spielberg                                   Schindler's List
# 9        Christopher Nolan                                          Inception
# 10           David Fincher                                         Fight Club
# ...

# %% [markdown]
# ## Difficuty => 7

# %% [markdown]
# ### Print out the released date, title, and the season (winter, spring, summer, fall) in which each movie was released. Let's assume for simplicity sake that seasons end at the end of each month instead of on the 21st.

# %%
import datetime as dt     

def season(date):
    if date.month >= 10:
        return "winter"
    elif date.month >= 7:
        return "fall"
    elif date.month >= 4:
        return "summer"
    elif date.month >= 1 :
        return "spring"
    else:
        return "N/A"

df_imdb = pd.read_sql("SELECT released,title FROM website_imdb",engine)

df_imdb.released = pd.to_datetime(df_imdb.released, format = '%Y-%m-%d')

df_imdb['season'] = df_imdb.released.apply(season)

df_imdb.head()
# Out:
#     released                    title  season
# 0 1996-02-23                 La Haine  spring
# 1 1998-01-09        Good Will Hunting  spring
# 2 2014-10-15                 Whiplash  winter
# 3 1956-11-19            Seven Samurai  winter
# 4 1981-06-12  Raiders of the Lost Ark  summer

# %% [markdown]
# ### Print out the released date, title, and the relation to today's date (disregard year). If the movie came out before today's month, print 'before' in the relationship column. If the movie came out after todays month, print out 'after' in the relationship column. If the movie was released in the same month, but not the same day, print out 'close'. If the movie came out on today's day and month print 'match'

# %%
def before_after_month(date):
    today = pd.to_datetime('today')
    
    if date.month < today.month:
        return "before"
    if date.month > today.month:
        return "after"
    elif date.month == today.month and date.day != today.day:
        return "close"
    elif date.month == today.month and date.day == today.day:
        return "match"
    else:
        return "N/A"

df_imdb['relationship'] = df_imdb.released.apply(before_after_month)

df_imdb.head()
# Out:
#     released                    title  season relationship
# 0 1996-02-23                 La Haine  spring       before
# 1 1998-01-09        Good Will Hunting  spring       before
# 2 2014-10-15                 Whiplash  winter       before
# 3 1956-11-19            Seven Samurai  winter        close
# 4 1981-06-12  Raiders of the Lost Ark  summer       before

# %% [markdown]
# ## Difficulty => 9

# %% [markdown]
# ### There is another table in my database called 'trump_tweets'. Print out all the times Trump has sent a tweet with a movie title in the text. The movie title must have a length greater than 1.

# %%
def title_in_tweet(tweet):
    # Build dictionary with list of words in movie
    dicty_movie = {}
    for title in df_imdb.title:
        dicty_movie[title] = []
        
        for word in title.split(" "):
            dicty_movie[title].append(word)
    
    # Build list of words in tweet
    listy_tweet = []
    for word in tweet.split(" "):
        listy_tweet.append(word)
        
    # Check if any word in tweet is in movie title
    for word in listy_tweet:
        for title in dicty_movie:
            if word in dicty_movie[title]:
                return title

df_tt['in_movie'] = df_tt.text.apply(title_in_tweet)

df_tt.head()
# Out:
#    index            id          created_at  \
# 0      0  7.656299e+17  8/16/2016 19:22:57
# 1      1  7.587319e+17  7/28/2016 18:32:31
# 2      2  7.583505e+17  7/27/2016 17:16:56
# 3      3  7.575775e+17  7/25/2016 14:05:27
# 4      4  7.536034e+17  7/14/2016 14:53:46
#
#                                                 text  \
# 0  It's just a 2-point race, Clinton 38%, Trump 3...
# 1  "@LallyRay: Poll: Donald Trump Sees 17-Point P...
# 2  Great new poll - thank you!\n#MakeAmericaGreat...
# 3  Great POLL numbers are coming out all over. Pe...
# 4  Another new poll. Thank you for your support! ...
#
#                        in_movie
# 0         It's a Wonderful Life
# 1  Once Upon a Time in the West
# 2              The Great Escape
# 3              The Great Escape
# 4           Requiem for a Dream

# %% [markdown]
# ### Print out a movie if it is included in the following groups:
# * Has the longest runtime
# * Is created by the director who has the most imdbvotes
# * Has been translated into more than 4 languages
# * Has won 2 Oscars
#
# ### Make sure each movie is printed out at most one time!

# %%
oscar_index = df_imdb_all[df_imdb_all['title'] == "Whiplash"].index.tolist()[0]

df_imdb_all['language']
# Out:
# 0                                               English
# 1                                               English
# 2      English, German, Hebrew, Spanish, Arabic, Nepali
# 3     French, English, Spanish, German, Italian, Rus...
# 4             English, German, French, Russian, Spanish
# 5                                               English
# 6                                               English
# 7                                      English, Spanish
# 8                                               English
# 9                                                 Hindi
# 10                      English, Hebrew, German, Polish
# 11                                   English, Cantonese
# 12                                      English, German
# 13                  English, Hungarian, Spanish, French
# 14                                              English
# 15                                              English
# 16                                      French, English
# ...

# %%
listy_four_language_movies = []
    
for x in df_imdb_all.language:
    if len(x.split(",")) > 4:
        language_index = df_imdb_all[df_imdb_all['language'] == x].index.tolist()[0]
        language_title = df_imdb_all.ix[[language_index], ['title']].values[0][0]
        listy_four_language_movies.append(language_title)
        


            
            
listy_four_language_movies
# Out:
# [u'Raiders of the Lost Ark',
#  u'The Wages of Fear',
#  u'The Great Escape',
#  u'Blade Runner',
#  u'The Godfather: Part II']

# %%
def filter_movie(movie):
    max_movie_name = df_imdb_all[df_imdb_all.runtime == max(df_imdb_all.runtime)]['title'].values[0]
    max_director_votes = df_imdb_all[df_imdb_all.imdbVotes == max(df_imdb_all.imdbVotes)]['title'].values[0]
    
    listy_oscars = []
    for x in df_imdb_all.awards:
        for y in x.split(". "):
            if y == "Won 2 Oscars":
                oscar_index = df_imdb_all[df_imdb_all['awards'] == x].index.tolist()[0]
                oscar_title = df_imdb_all.ix[[oscar_index], ['title']].values[0][0]

                listy_oscars.append(oscar_title)
    
    listy_four_language_movies = []
    for x in df_imdb_all.language:
        if len(x.split(",")) > 4:
            language_index = df_imdb_all[df_imdb_all['language'] == x].index.tolist()[0]
            language_title = df_imdb_all.ix[[language_index], ['title']].values[0][0]
            listy_four_language_movies.append(language_title)
            
    
    # Has the longest runtime
    if movie == max_movie_name:
        return "Max Runtime Move: " + max_movie_name
    # Is created by the director who has the most imdbvotes
    elif movie == max_director_votes:
        return "Director: " + max_director_votes
    # Has won 2 Oscars
    elif movie in listy_oscars:
        return "Awards: " + df_imdb_all.ix[df_imdb_all.title == movie]['awards'].values[0][0]
    # > 4 Languages
    elif movie in listy_four_language_movies:
        return "Languages: " + df_imdb_all.ix[df_imdb_all.title == movie]['language'].values[0][0]
    
    else:
        return "N/A"

df_imdb['in_movie_2'] = df_imdb.title.apply(filter_movie)

df_imdb.head()
# Out:
#     released                    title  season relationship    in_movie_2
# 0 1996-02-23                 La Haine  spring       before           N/A
# 1 1998-01-09        Good Will Hunting  spring       before     Awards: W
# 2 2014-10-15                 Whiplash  winter       before           N/A
# 3 1956-11-19            Seven Samurai  winter        close           N/A
# 4 1981-06-12  Raiders of the Lost Ark  summer       before  Languages: E

# %% [markdown]
# ## Good job on completing this assignment! You should now be ready for any SQL-based problem thrown at you in the future!
#
# #### If you haven't finished the assignment, scroll back up. This message isn't for you.
